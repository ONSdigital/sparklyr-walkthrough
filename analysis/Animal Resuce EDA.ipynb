# %%
# Load libraries
import pandas as pd

# %%
# Load the Data
# Data saved in Windows encoding Cp1255
raw_df = pd.read_csv('../data/Animal Rescue incidents attended by LFB from Jan 2009.csv', encoding='cp1255')

# %%
raw_df.head()
# Out:
#   IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 0         139091  01/01/2009 03:01     2009  2008/09  Special Service
# 1         275091  01/01/2009 08:51     2009  2008/09  Special Service
# 2        2075091  04/01/2009 10:07     2009  2008/09  Special Service
# 3        2872091  05/01/2009 12:27     2009  2008/09  Special Service
# 4        3553091  06/01/2009 15:23     2009  2008/09  Special Service
#
#    PumpCount  PumpHoursTotal  HourlyNotionalCost(£)  IncidentNotionalCost(£)  \
# 0        1.0             2.0                    255                    510.0
# 1        1.0             1.0                    255                    255.0
# 2        1.0             1.0                    255                    255.0
# 3        1.0             1.0                    255                    255.0
# 4        1.0             1.0                    255                    255.0
#
#                             FinalDescription       ...          WardCode  \
# ...

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5898 entries, 0 to 5897
# Data columns (total 26 columns):
# IncidentNumber                5898 non-null object
# DateTimeOfCall                5898 non-null object
# CalYear                       5898 non-null int64
# FinYear                       5898 non-null object
# TypeOfIncident                5898 non-null object
# PumpCount                     5860 non-null float64
# PumpHoursTotal                5860 non-null float64
# HourlyNotionalCost(£)         5898 non-null int64
# IncidentNotionalCost(£)       5860 non-null float64
# FinalDescription              5895 non-null object
# AnimalGroupParent             5898 non-null object
# OriginofCall                  5898 non-null object
# PropertyType                  5898 non-null object
# PropertyCategory              5898 non-null object
# SpecialServiceTypeCategory    5898 non-null object
# SpecialServiceType            5898 non-null object
# ...

# %%
# Lets drop some columns that are about geographic position for now
unwanted_cols = ['Easting_m', 'Northing_m', 'Easting_rounded', 'Northing_rounded', 'BoroughCode', 'WardCode']
df = raw_df.drop(unwanted_cols, axis=1)

# %%
df
# Out:
#        IncidentNumber    DateTimeOfCall  CalYear  FinYear   TypeOfIncident  \
# 0              139091  01/01/2009 03:01     2009  2008/09  Special Service
# 1              275091  01/01/2009 08:51     2009  2008/09  Special Service
# 2             2075091  04/01/2009 10:07     2009  2008/09  Special Service
# 3             2872091  05/01/2009 12:27     2009  2008/09  Special Service
# 4             3553091  06/01/2009 15:23     2009  2008/09  Special Service
# 5             3742091  06/01/2009 19:30     2009  2008/09  Special Service
# 6             4011091  07/01/2009 06:29     2009  2008/09  Special Service
# 7             4211091  07/01/2009 11:55     2009  2008/09  Special Service
# 8             4306091  07/01/2009 13:48     2009  2008/09  Special Service
# 9             4715091  07/01/2009 21:24     2009  2008/09  Special Service
# 10            5186091  08/01/2009 14:34     2009  2008/09  Special Service
# ...

# %%
# Lest start to investigate the columns
# Incident Number, is this unique?

# %%
df['IncidentNumber'].shape[0] == df['IncidentNumber'].nunique()
# Out:
# True

# %%
# Filter ing by yea
